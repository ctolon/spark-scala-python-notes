# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
import os

# %%
spark = SparkSession.builder \
.appName("join_products") \
.config("spark.executor.memory", "2g") \
.config("spark.driver.memory", "4g") \
.master("local[*]") \
.getOrCreate()
# Out:
# 23/04/15 14:04:56 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
sc = spark.sparkContext
sc.setLogLevel("ERROR")

# %%
current_dir = os.getcwd()
products_path = f"{current_dir}/products.csv"
order_items_path = f"{current_dir}/order_items.csv"

# %%
productsRDD = sc.textFile(products_path) \
.filter(lambda line: "productCategoryId" not in line)

order_itemsRDD = sc.textFile(order_items_path) \
.filter(lambda line: "orderItemName" not in line)

# %%
print(productsRDD.take(5))
print("\n ==== \n")
print(order_itemsRDD.take(5))
# Out:
# ['1,2,Quest Q64 10 FT. x 10 FT. Slant Leg Instant U,,59.98,http://images.acmesports.sports/Quest+Q64+10+FT.+x+10+FT.+Slant+Leg+Instant+Up+Canopy', "2,2,Under Armour Men's Highlight MC Football Clea,,129.99,http://images.acmesports.sports/Under+Armour+Men%27s+Highlight+MC+Football+Cleat", "3,2,Under Armour Men's Renegade D Mid Football Cl,,89.99,http://images.acmesports.sports/Under+Armour+Men%27s+Renegade+D+Mid+Football+Cleat", "4,2,Under Armour Men's Renegade D Mid Football Cl,,89.99,http://images.acmesports.sports/Under+Armour+Men%27s+Renegade+D+Mid+Football+Cleat", '5,2,Riddell Youth Revolution Speed Custom Footbal,,199.99,http://images.acmesports.sports/Riddell+Youth+Revolution+Speed+Custom+Football+Helmet']
#
#  ====
#
# ['1,1,957,1,299.98,299.98', '2,2,1073,1,199.99,199.99', '3,2,502,5,250.0,50.0', '4,2,403,1,129.99,129.99', '5,4,897,2,49.98,24.99']

# %%
def make_order_items_pair_rdd(line: str):
    orderItemName = line.split(",")[0]
    orderItemOrderId = line.split(",")[1]
    orderItemProductId = line.split(",")[2]
    orderItemQuantity = line.split(",")[3]
    orderItemSubTotal = line.split(",")[4]
    orderItemProductPrice = line.split(",")[5]
    
    return (orderItemProductId, (orderItemName,orderItemOrderId,orderItemQuantity,orderItemSubTotal,orderItemProductPrice))

# %%
order_items_pairRDD = order_itemsRDD.map(make_order_items_pair_rdd)
order_items_pairRDD.take(5)
# Out:
# [('957', ('1', '1', '1', '299.98', '299.98')),
#  ('1073', ('2', '2', '1', '199.99', '199.99')),
#  ('502', ('3', '2', '5', '250.0', '50.0')),
#  ('403', ('4', '2', '1', '129.99', '129.99')),
#  ('897', ('5', '4', '2', '49.98', '24.99'))]

# %%
def make_products_pair_rdd(line: str):
    productId = line.split(",")[0]
    productCategoryId = line.split(",")[1]
    productName = line.split(",")[2]
    productDescription = line.split(",")[3]
    productPrice = line.split(",")[4]
    productImage = line.split(",")[5]
    
    return (productId, (productCategoryId, productName, productDescription, productPrice, productImage))

# %%
products_pairRDD = productsRDD.map(make_products_pair_rdd)
products_pairRDD.take(5)
# Out:
# [('1',
#   ('2',
#    'Quest Q64 10 FT. x 10 FT. Slant Leg Instant U',
#    '',
#    '59.98',
#    'http://images.acmesports.sports/Quest+Q64+10+FT.+x+10+FT.+Slant+Leg+Instant+Up+Canopy')),
#  ('2',
#   ('2',
#    "Under Armour Men's Highlight MC Football Clea",
#    '',
#    '129.99',
#    'http://images.acmesports.sports/Under+Armour+Men%27s+Highlight+MC+Football+Cleat')),
#  ('3',
#   ('2',
#    "Under Armour Men's Renegade D Mid Football Cl",
#    '',
#    '89.99',
#    'http://images.acmesports.sports/Under+Armour+Men%27s+Renegade+D+Mid+Football+Cleat')),
#  ('4',
#   ('2',
#    "Under Armour Men's Renegade D Mid Football Cl",
#    '',
#    '89.99',
#    'http://images.acmesports.sports/Under+Armour+Men%27s+Renegade+D+Mid+Football+Cleat')),
#  ('5',
#   ('2',
#    'Riddell Youth Revolution Speed Custom Footbal',
#    '',
#    '199.99',
#    'http://images.acmesports.sports/Riddell+Youth+Revolution+Speed+Custom+Football+Helmet'))]

# %%
order_items_products_pairRDD = order_items_pairRDD.join(products_pairRDD)

# %%
order_items_products_pairRDD.collect()
# Out:
# [('957',
#   (('1', '1', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('9', '5', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('12', '5', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('15', '7', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('34', '12', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('59', '19', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('68', '23', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('79', '28', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('80', '28', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('94', '34', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('97', '36', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('109', '43', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('121', '49', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('125', '50', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('132', '56', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('142', '59', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('151', '62', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('161', '65', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('164', '66', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('167', '68', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('171', '70', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('217', '96', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('230', '101', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('232', '101', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('237', '104', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('247', '107', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('261', '113', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('264', '115', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('265', '115', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('266', '116', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('285', '121', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('286', '121', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('291', '122', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('307', '131', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('320', '136', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('327', '140', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('337', '143', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('344', '146', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('362', '154', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('380', '162', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('381', '162', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('382', '162', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('405', '168', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('423', '174', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('425', '175', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('440', '181', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('453', '186', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('462', '190', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('467', '192', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('511', '209', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('517', '213', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('526', '216', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('527', '216', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('570', '231', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('589', '239', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('592', '239', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('597', '241', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('605', '243', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('614', '246', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('620', '247', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('638', '253', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('647', '256', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('684', '273', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('686', '274', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('701', '281', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('723', '287', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('736', '292', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('743', '294', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('753', '300', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('758', '302', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('781', '312', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('786', '314', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('819', '330', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('829', '333', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('838', '336', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('842', '338', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('853', '345', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('881', '354', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('882', '355', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('925', '368', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('930', '372', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('952', '384', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('958', '385', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('978', '393', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('985', '398', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('987', '398', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('991', '399', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1001', '403', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1019', '411', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1036', '417', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1045', '419', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1052', '423', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1067', '430', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1069', '430', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1083', '437', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1087', '441', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1089', '442', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1096', '443', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1099', '447', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1101', '449', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1123', '458', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1157', '472', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1182', '480', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1186', '483', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1188', '484', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1189', '484', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1199', '486', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1203', '487', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1204', '488', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1205', '489', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1212', '492', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1229', '498', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1257', '508', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1279', '517', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1281', '517', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1284', '518', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1287', '520', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1290', '521', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1291', '521', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('1346', '540', '1', '299.98', '299.98'),
#    ('43',
#     "Diamondback Women's Serene Classic Comfort Bi",
#     '',
#     '299.98',
#     'http://images.acmesports.sports/Diamondback+Women%27s+Serene+Classic+Comfort+Bike+2014'))),
#  ('957',
#   (('